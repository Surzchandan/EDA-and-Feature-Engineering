# %% [markdown]
# # Faeture Engineering for House Pricing

# %% [markdown]
# We will  be perform the below steps
# 1. Handling Missing values
# 2. Temporal Variables
# 3. Handle categorical varibles -remove rare labels
# 4. Standardize the values of the variables to the range

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset.shape
# Out:
# (1460, 81)

# %%
from sklearn.model_selection import train_test_split

# %%
x=dataset.iloc[:,1:81]
y=dataset.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_spilt(x,y,test_size=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\370011~1\AppData\Local\Temp/ipykernel_18624/1624377674.py in <module>
# ----> 1 x_train,x_test,y_train,y_test=train_test_spilt(x,y,test_size=0.1)
#
# NameError: name 'train_test_spilt' is not defined

# %%
x=dataset.iloc[:,1:81]
y=dataset.iloc[:,-1]
"""x=dataset.drop(["Id","SalePrice"],axis=1)
y=dataset["SalePrice"]"""
# Out:
# 'x=dataset.drop(["Id","SalePrice"],axis=1)\ny=dataset["SalePrice"]'

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 989           60       FV         65.0     8125   Pave   NaN      Reg
# 100           20       RL          NaN    10603   Pave   NaN      IR1
# 1215          20       RL         99.0     7094   Pave   NaN      IR1
# 1310          20       RL        100.0    17500   Pave   NaN      Reg
# 111           80       RL          NaN     7750   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 733           20       RL         80.0    10000   Pave   NaN      Reg
# 47            20       FV         84.0    11096   Pave   NaN      Reg
# 729           30       RM         52.0     6240   Pave  Grvl      Reg
# 348          160       RL         36.0     2448   Pave   NaN      Reg
# 766           60       RL         80.0    10421   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
## Missing Values
feature_nan=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>=1]

# %%
feature_nan
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']
